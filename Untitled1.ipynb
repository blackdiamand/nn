# %%
import tensorflow_datasets as tfds
from tensorflow.keras.utils import to_categorical

## Loading images and labels
dataset = tfds.ImageFolder(
    "data/hw11Data",
)
print(dataset.info)

train_ds = dataset.as_dataset(split='train', shuffle_files=True)
tfds.show_examples(train_ds, dataset.info)

test_ds = dataset.as_dataset(split='validation', shuffle_files=True)
tfds.show_examples(test_ds, dataset.info)
# Out:
# tfds.core.DatasetInfo(
#     name='image_folder',
#     full_name='image_folder/1.0.0',
#     description="""
#     Generic image classification dataset.
#     """,
#     homepage='https://www.tensorflow.org/datasets/catalog/image_folder',
#     data_dir='/Users/admin/tensorflow_datasets/image_folder/1.0.0',
#     file_format=tfrecord,
#     download_size=Unknown size,
#     dataset_size=Unknown size,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=uint8),
#         'image/filename': Text(shape=(), dtype=string),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=6),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=415, num_shards=1>,
#         'validation': <SplitInfo num_examples=415, num_shards=1>,
#     },
#     citation="""""",
# )

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

## Loading VGG16 model
base_model = VGG16(weights="imagenet", include_top=False, input_shape=dataset.element_spec[0].shape)
base_model.trainable = False ## Not trainable weights

## Preprocessing input
train_ds = preprocess_input(train_ds) 
test_ds = preprocess_input(test_ds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 5
#       2 from tensorflow.keras.applications.vgg16 import preprocess_input
#       4 ## Loading VGG16 model
# ----> 5 base_model = VGG16(weights="imagenet", include_top=False, input_shape=dataset.element_spec[0].shape)
#       6 base_model.trainable = False ## Not trainable weights
#       8 ## Preprocessing input
#
# AttributeError: 'ImageFolder' object has no attribute 'element_spec'
