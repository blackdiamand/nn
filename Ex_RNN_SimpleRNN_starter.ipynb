# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from collections import Counter
import numpy as np
import re

# P1) Analyze the dataset
corpus = [line.strip() for line in open('data/TheTimeMachine.txt') if line.strip()][2:]
print("\n".join(corpus[:10]))

corpus = [re.sub('[^A-Za-z0-9]+', ' ', line).lower() for line in corpus]
corpus = [re.sub(' +', ' ', line) for line in corpus]
corpus = [word for line in corpus for word in line.split()]

vocab_size = 5000
tkn_counter = Counter([word for word in corpus])
vocab = {word: idx for idx, (word, _) in enumerate(tkn_counter.most_common(vocab_size))}
vocab["/UNK"] = len(vocab)

class TextCorpusDataset(tf.keras.utils.Sequence):
    def __init__(self, corpus, vocab, snippet_len=50):
        self.corpus = corpus
        self.snippet_len = snippet_len
        # Vocabulary (word-to-index mapping)
        self.vocab = vocab
        # Inverse vocabulary (index-to-word mapping)
        self.inv_vocab = {idx: word for word, idx in self.vocab.items()}

    def convert2idx(self, word_sequence):
        return [self.vocab.get(word, self.vocab["/UNK"]) for word in word_sequence]

    def convert2words(self, idx_sequence):
        return [self.inv_vocab[idx] for idx in idx_sequence]

    def __len__(self):
        return (len(self.corpus) - self.snippet_len) // self.snippet_len

    def __getitem__(self, idx):
        idx = idx * self.snippet_len
        snippet = self.corpus[idx:idx+self.snippet_len]
        snippet = np.array(self.convert2idx(snippet))
        return snippet

# Test dataset function
dataset = TextCorpusDataset(corpus, vocab)
snippet = dataset[123]
print("\nRandom snippet from the corpus.")
print("  * Token IDS:\t", snippet)
print("  * Words:\t\t", " ".join([dataset.inv_vocab[i] for i in snippet]))
# Out:
# The Time Traveller (for so it will be convenient to speak of him)
# was expounding a recondite matter to us. His grey eyes shone and
# twinkled, and his usually pale face was flushed and animated. The
# fire burned brightly, and the soft radiance of the incandescent
# lights in the lilies of silver caught the bubbles that flashed and
# passed in our glasses. Our chairs, being his patents, embraced and
# caressed us rather than submitted to be sat upon, and there was that
# luxurious after-dinner atmosphere when thought roams gracefully
# free of the trammels of precision. And he put it to us in this
# way--marking the points with a lean forefinger--as we sat and lazily
#
# Random snippet from the corpus.
#   * Token IDS:	 [  13    1  377   14    4  506  697   85   18   20  855 2616    1    6
#    36    5  585 2617    6 1632   59    4 1168   85    0 2618    3 2619
#  2620   17    5  149    5    4  513 2621    0 2622    3   82 1633   39
#  1633   33 1634  256    7    9  113 1056]
#   * Words:		 as i travelled at a high velocity through time this scarcely mattered i was so to speak attenuated was slipping like a vapour through the interstices of intervening substances but to come to a stop involved the jamming of myself molecule by molecule into whatever lay in my way meant

# %%
# Define SimpleRNN

class SimpleRNN(tf.keras.Model):
    def __init__(self, vocab_size, hidden_dim):
        super(SimpleRNN, self).__init__()
        self.vocab_size, self.hidden_dim = vocab_size, hidden_dim

        self.linear_inp2state = layers.Dense(hidden_dim)
        self.linear_state2state = layers.Dense(hidden_dim)
        self.linear_state2out = layers.Dense(vocab_size)

    def initial_state(self, batch_size, device):
        return tf.zeros((batch_size, self.hidden_dim), dtype=tf.float32)

    def call(self, inp_seq, state=None):
        n_steps, batch_size = inp_seq.shape[:2]

        # If state is not provided, get initial state.
        if state is None:
            state = self.initial_state(batch_size, inp_seq.device)

        outputs = []
        for t in range(n_steps):
            state = tf.tanh(self.linear_inp2state(inp_seq[t]) + self.linear_state2state(state))
            out = self.linear_state2out(state)
            outputs.append(out)

        return tf.stack(outputs, 0), state

hidden_dim = 256
model = SimpleRNN(vocab_size, hidden_dim)

sentence = "today is too darn cold".split()
# text to index, must have size 5, 1, 4582 (Note that in RNNs the batch is often the 2nd dimension, not the first)
inp = tf.constant(dataset.convert2idx(sentence))[:, tf.newaxis]
inp = tf.one_hot(inp, len(vocab), dtype=tf.float32)
Yhat, new_state = model(inp)
Yhat = tf.argmax(Yhat, axis=-1)
print(Yhat.numpy().flatten())
print(dataset.convert2words(Yhat.numpy().flatten()))
# Out:
# [2153 3557 1744 3975  467]
# ['forbidden', 'smaller', 'heels', 'leal', 'everything']

# %%
def generate(prefix, num_preds, model, vocab):
    prefix = tf.constant(dataset.convert2idx(prefix.split()), dtype=tf.int32).numpy()

    state, outputs = None, [prefix[0]]
    for i in range(1, len(prefix) + num_preds):
        # Prepare one token at a time to feed the model
        inp = tf.one_hot(outputs[-1], len(vocab), dtype=tf.float32)[tf.newaxis, tf.newaxis]

        # Compute the prediction for the next token
        yhat, state = model(inp, state)

        if i < len(prefix):
            # During warmup (while parsing the prefix), we ignore the model prediction
            outputs.append(prefix[i])
        else:
            # Otherwise, append the model prediction to the output list
            yhat = tf.argmax(yhat[0, 0], axis=-1).numpy()
            outputs.append(yhat)
    return ' '.join([dataset.inv_vocab[tkn] for tkn in outputs])

generate('i do not mean to ask you to accept anything', 10, model, vocab)
# Out:
# 'i do not mean to ask you to accept anything dozens founded destroyed against half reality signal unhinged composite chair'

# %%
def train_on_sequence(seq, model, optimizer, unroll=5):
    batch_size, num_tokens = seq.shape

    total_loss, state = 0., None
    for i in range(0, num_tokens-unroll-1, unroll):
        if state is not None:
            state = tf.stop_gradient(state)
        # Define the input sequence along which we will unroll the RNN
        x = tf.transpose(seq[:, i:i+unroll])
        y = tf.transpose(seq[:, i+unroll:i+unroll+unroll])

        x = tf.one_hot(x, len(vocab), dtype=tf.float32)
        with tf.GradientTape() as tape:
            y_hat, state = model(x, state)
            loss = tf.reduce_mean(tf.keras.losses.sparse_categorical_crossentropy(y, tf.reshape(y_hat, (-1, len(vocab))),from_logits=True))
        total_loss += loss.numpy()

        gradients = tape.gradient(loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    n_batches = (num_tokens-unroll-1) // unroll
    return total_loss / n_batches

def fit(model, loader, vocab, lr, num_epochs=100, unroll=5):
    optimizer = tf.optimizers.legacy.RMSprop(lr)
    test_prompt = 'i do not mean to ask you to accept anything'
    loader_size = len(list(loader))
    for epoch in range(num_epochs):
        total_loss = 0

        for sequence in loader:
            total_loss += train_on_sequence(sequence, model, optimizer, unroll=unroll)
        total_loss /= loader_size

        print(f'Epoch {epoch} | Perplexity {np.exp(total_loss):.1f}. Loss: {total_loss:.3f}')
        print(generate(test_prompt, 50, model, vocab))

num_epochs, lr = 100, 0.001
dataset = TextCorpusDataset(corpus, vocab, 100)
loader = tf.data.Dataset.from_generator(lambda: iter(dataset), output_signature=tf.TensorSpec(shape=(100,), dtype=tf.int32)).batch(32)
model = SimpleRNN(len(vocab), hidden_dim)
fit(model, loader, vocab, lr, num_epochs, unroll=5)
# Out:
# Epoch 0 | Perplexity 1077.7. Loss: 6.983
# i do not mean to ask you to accept anything the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# Epoch
# i do not mean to ask you to accept anything it way there had the i and that on traveller to at this i time to that still he of and and all to at with that time for in the the i was an to to thought and the little have with a think that time for be on
# Epoch 52 | Perplexity 77.6. Loss: 4.352
# i do not mean to ask you to accept anything it way i had the i i very that my he i to have before i was i my i as it of that had the and it the only i some this and had time i and that on must time all you the it i it was the
# Epoch 53 | Perplexity 74.9. Loss: 4.316
# i do not mean to ask you to accept anything it in a had the for had but on now to at a i to of be that one it be into the that it that the was for it i had with but our over the man and into the a of one the i and the and some
# Epoch 54 | Perplexity 72.0. Loss: 4.277
# i do not mean to ask you to accept anything it in have that a have than a have that had thing be you was that on of time for so the it be in and of down the the machine was the it had the had the years was a to of which and or it one but i
# Epoch 55 | Perplexity 70.3. Loss: 4.253
# i do not mean to ask you to accept anything it be he that it after and so the that into that it last of were the what it and that the the the i was no it i thought and the to there of that of the would of time to was it that was a the at i
# Epoch 56 | Perplexity 68.1. Loss: 4.220
# i do not mean to ask you to accept anything it saw a that in of the moment the still so out no this not this was had to i my that and it had i i it that only he that i was it that been some this to had i i been that had world had i had
# Epoch 57 | Perplexity 66.3. Loss: 4.194
# i do not mean to ask you to accept anything it was a and the a to of the so and a and it with towards at i at to and by i was of said to a the i a out with his i began to me be it and to all come the these that was the to
# Epoch 58 | Perplexity 64.0. Loss: 4.158
# i do not mean to ask you to accept anything it was a he that a in a the been of what be be the was of and the of me and that seemed a the i was a and had i could the at was to the a went the i very the and so and that its strange
# Epoch 59 | Perplexity 62.5. Loss: 4.135
# i do not mean to ask you to accept anything it way a is thing a little of me to machine i a old of the he a and i upon i the i could the the see of the at the was a began to the thing that a all my had machine i had among the the i
# Epoch 60 | Perplexity 61.1. Loss: 4.113
# i do not mean to ask you to accept anything it way a is thing me be on the was all of the you to an the something of at but my me and my time i at think that time to the i again down the time then in the in at the the and i the could of
# Epoch 61 | Perplexity 60.2. Loss: 4.098
# i do not mean to ask you to accept anything it see it that that all of all that the would had a to this me so with a time me the was here at the traveller of you you as i i you that that traveller of the at i the was night and the looked had up i
# Epoch 62 | Perplexity 58.9. Loss: 4.075
# i do not mean to ask you to accept anything it see it that that a the a the i was a and i saw a the first i i no my that to had the the world was the machine i to my me i was of i had to of it that with time of this i had
# Epoch 63 | Perplexity 58.1. Loss: 4.061
# i do not mean to ask you to accept anything it way it that it of said the be the i was i at time to then and that the he and i then to his felt i then and that a do at i to a and of i i and that of they and a machine i with
# Epoch 64 | Perplexity 57.1. Loss: 4.044
# i do not mean to ask you to accept anything it see it that felt a to a a i of a my that had in had the the it said with a to to this that little back the one just which so now i this that it with in all you that that is it the moment all
# Epoch 65 | Perplexity 56.6. Loss: 4.035
# i do not mean to ask you to accept anything it will you be it that that and the little have have this so it that the with my me was it the that had to i it you that time for this time this not had a in and a a round a round of the i i the
# Epoch 66 | Perplexity 56.2. Loss: 4.030
# i do not mean to ask you to accept anything it will a the me again my and of how to and i you that of i you it that my you that it the that was it the the upon at i these felt the time traveller then at the i he and that i would into the there
# Epoch 67 | Perplexity 55.4. Loss: 4.015
# i do not mean to ask you to accept anything it with a time of the it that only to this i was i that any my this here this i had very that of for the like is i of and of that it that it that that time then my but a it of me at was what
# Epoch 68 | Perplexity 55.0. Loss: 4.008
# i do not mean to ask you to accept anything it with it i until with my i it that me there the and of the to of a that a is is is is our know it that it that the one that me was it i of that its his in its with my time of all some
# Epoch 69 | Perplexity 54.3. Loss: 3.995
# i do not mean to ask you to accept anything it with a i that a a was by could a the to to a was i it that the thing it i and the for i you that time of that myself that all the time of that as they and time but and it that it of the
# Epoch 70 | Perplexity 53.9. Loss: 3.986
# i do not mean to ask you to accept anything it with a and that of there and that of the the that was was a a was that a a by had by had had had had it had only to it a the it a a and but the i and the of to the but our this
# Epoch 71 | Perplexity 53.1. Loss: 3.973
# i do not mean to ask you to accept anything it some that that for that the so it that in in not this if a they now said you s some to or it that man at that this with the i the the that in in the the of the was that enough the this of was the
# Epoch 72 | Perplexity 52.4. Loss: 3.958
# i do not mean to ask you to accept anything it a a that of that out of the i of the as they the that and in the the of that a we the i as it that only time for i not to a time to i myself that that to this of it that that with that
# Epoch 73 | Perplexity 51.4. Loss: 3.939
# i do not mean to ask you to accept anything it not it that the that the the was would of as it to of had i of that the that the a man at that i of the and as the was the to i i for that the time of which but i was time but i upon
# Epoch 74 | Perplexity 50.8. Loss: 3.928
# i do not mean to ask you to accept anything it was to to i a i of that that of this at i to again myself that these was i moment a i had at i had these had that all of was have have i of that that thing and not it that said that this have this
# Epoch 75 | Perplexity 50.1. Loss: 3.913
# i do not mean to ask you to accept anything it will still the of the that it that the think a time of the i was was i had i could it a there of that and as you i as i from looked to i was was of have by first and the it that the a is
# Epoch 76 | Perplexity 49.2. Loss: 3.896
# i do not mean to ask you to accept anything it will still the of with they that this so this with the i the that had in to for a the it of i the was and the the i was for that i it the that had the the had at the the to there the i of
# Epoch 77 | Perplexity 48.4. Loss: 3.879
# i do not mean to ask you to accept anything it had i could it the but was i i i and with my time with was i were that i could i the i and them but to i saw a in in to i is you to i and that the that are there a all of its
# Epoch 78 | Perplexity 47.4. Loss: 3.859
# i do not mean to ask you to accept anything it that a the that to you that a to not to you the that to you that time for that time be man at with a to all that time to a all that to to the i was the to again i i the was all there and
# Epoch 79 | Perplexity 46.2. Loss: 3.834
# i do not mean to ask you to accept anything it with a to it is i and that my and some white of no to of i for the i the the of and to the it you i as the two from and me i the was i the i from it that with was before at this
# Epoch 80 | Perplexity 45.3. Loss: 3.813
# i do not mean to ask you to accept anything it with a to it is i and a little have by this it so it that the time it the it the the had in i i into that as the the the the my i was i had i i have about there the that had in in
# Epoch 81 | Perplexity 44.5. Loss: 3.796
# i do not mean to ask you to accept anything it that a was that to it must have the the that been was be have at the was a the that i was like a i the a to all it think that a then by i upon no of the i light that the had the i at
# Epoch 82 | Perplexity 43.6. Loss: 3.776
# i do not mean to ask you to accept anything it with a upon upon round some the of the at the to to all of it i a with that i it the some its my i at that had up at at was these a is i a a and i you a and i very to what
# Epoch 83 | Perplexity 42.8. Loss: 3.756
# i do not mean to ask you to accept anything it that a upon was long for that more of the the one it a and that the the the had was i at the to him i at the the the and that as the be here the the me was to about of that to was the time
# Epoch 84 | Perplexity 42.0. Loss: 3.738
# i do not mean to ask you to accept anything it that a upon you that it that only of that here not it i again the with my i it you s some you in i had the and to a the time i the with my and the my i in it the i the machine i there
# Epoch 85 | Perplexity 41.2. Loss: 3.718
# i do not mean to ask you to accept anything it have a upon have again had time of the he that and a to to the i was and the little that a a a the a and was i i the that to round a little that the this this was had it that the you but and
# Epoch 86 | Perplexity 40.4. Loss: 3.699
# i do not mean to ask you to accept anything it have a the at again i and here not and was that to would our to it be things that in the time time with and it at the the come the s as the the to to at i i of that my of and i them to
# Epoch 87 | Perplexity 39.5. Loss: 3.675
# i do not mean to ask you to accept anything it have a the at again i and was of i no this that for was my i it from of that the the was i it i with that and this you it up i the and my and of as i of the of one i a the
# Epoch 88 | Perplexity 38.4. Loss: 3.648
# i do not mean to ask you to accept anything it that a think at with i of myself that all time i but you that time but the time it and with the to you the time came and with my of it that only he as i time of in about of the the he and to a
# Epoch 89 | Perplexity 37.5. Loss: 3.625
# i do not mean to ask you to accept anything it for a the i and the now to was at the the a i my i for that time my the time it said with think it the there me the we there might the i in the i i and that of this time so and with time
# Epoch 90 | Perplexity 36.7. Loss: 3.602
# i do not mean to ask you to accept anything it have a the of but you as i i you the what i and that to then even time came and all you the as i seemed was this with a with in up i could that on there and a of i but i the and it that
# Epoch 91 | Perplexity 36.1. Loss: 3.587
# i do not mean to ask you to accept anything it for a the i went the and that i a the and i my the that that some that our the the the was at a i of the that the round a was that the the had the was had a i of a i a i i
# Epoch 92 | Perplexity 35.6. Loss: 3.573
# i do not mean to ask you to accept anything it for a the i and i now to of that the was a have have the thing it with or my at the these could i the to and it i in i my the machine i it the or it the of me i that i my that
# Epoch 93 | Perplexity 34.9. Loss: 3.553
# i do not mean to ask you to accept anything it for a the i the i and the i but you as said you you a the you a time could i a the machine a a now then i is the said our this that this to you time but i said you that it for that the
# Epoch 94 | Perplexity 34.3. Loss: 3.534
# i do not mean to ask you to accept anything it for a the it that only now i one a the that it this a so at that the it of the that my see that it that into was as one in the the as i at that to my i i time for that time do a
# Epoch 95 | Perplexity 33.7. Loss: 3.518
# i do not mean to ask you to accept anything it for through that it that a was in a a and of a a now by could it was when of into for my the time be from that the of the time of the a here at a i to again and that the that it of the
# Epoch 96 | Perplexity 33.4. Loss: 3.509
# i do not mean to ask you to accept anything i for through that it you that my not to it you you to have is you time in the it i the a my this i i the that had in i my the it that it that the time then and moment looked i could i the i
# Epoch 97 | Perplexity 32.9. Loss: 3.493
# i do not mean to ask you to accept anything it for we the it that the and the i was the i had myself i had to i i i the or and the of the my air one time for a to i the i light the and my that that it that before was i i have
# Epoch 98 | Perplexity 32.4. Loss: 3.478
# i do not mean to ask you to accept anything it have into the a is a they that its it a but i it that do into machine i could the the and my i could i at and what there and a i i the that that and the i here that and was to and so the
# Epoch 99 | Perplexity 31.9. Loss: 3.463
# i do not mean to ask you to accept anything it have for so it but i thing it i only i said this this my some and my then that it and that the a the i again i and was and that which my of it that the the a i as was i went on and to

# %%
generate('today is too darn cold', 10, model, vocab)
# Out:
# '/UNK is too /UNK cold the i was to then i you to what i'
