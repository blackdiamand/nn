# %% [markdown]
# https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/images/transfer_learning.ipynb?force_kitty_mode=1&force_corgi_mode=1

# %% [markdown]
# # Transfer learning and fine-tuning

# %% [markdown]
# In this tutorial, you will learn how to classify images of cats and dogs by using transfer learning from a pre-trained network.
#
# A pre-trained model is a saved network that was previously trained on a large dataset, typically on a large-scale image-classification task. You either use the pretrained model as is or use transfer learning to customize this model to a given task.
#
# The intuition behind transfer learning for image classification is that if a model is trained on a large and general enough dataset, this model will effectively serve as a generic model of the visual world. You can then take advantage of these learned feature maps without having to start from scratch by training a large model on a large dataset.
#
# In this notebook, you will try two ways to customize a pretrained model:
#
# 1. Feature Extraction: Use the representations learned by a previous network to extract meaningful features from new samples. You simply add a new classifier, which will be trained from scratch, on top of the pretrained model so that you can repurpose the feature maps learned previously for the dataset.
#
#  You do not need to (re)train the entire model. The base convolutional network already contains features that are generically useful for classifying pictures. However, the final, classification part of the pretrained model is specific to the original classification task, and subsequently specific to the set of classes on which the model was trained.
#
# 1. Fine-Tuning: Unfreeze a few of the top layers of a frozen model base and jointly train both the newly-added classifier layers and the last layers of the base model. This allows us to "fine-tune" the higher-order feature representations in the base model in order to make them more relevant for the specific task.
#
# You will follow the general machine learning workflow.
#
# 1. Examine and understand the data
# 1. Build an input pipeline, in this case using Keras ImageDataGenerator
# 1. Compose the model
#    * Load in the pretrained base model (and pretrained weights)
#    * Stack the classification layers on top
# 1. Train the model
# 1. Evaluate model

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Data download

# %% [markdown]
# In this tutorial, you will use a dataset containing several thousand images of cats and dogs. Download and extract a zip file containing the images, then create a `tf.data.Dataset` for training and validation using the `tf.keras.utils.image_dataset_from_directory` utility. You can learn more about loading images in this [tutorial](https://www.tensorflow.org/tutorials/load_data/images).

# %%
#_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
#path_to_zip = tf.keras.utils.get_file('cats_and_dogs.zip', origin=_URL, extract=True)
PATH = 'data/hw11Data'
train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

BATCH_SIZE = 32
IMG_SIZE = (160, 160)

train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
                                                            shuffle=True,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE)
# Out:
# Found 415 files belonging to 6 classes.

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir,
                                                                 shuffle=True,
                                                                 batch_size=BATCH_SIZE,
                                                                 image_size=IMG_SIZE)
# Out:
# Found 415 files belonging to 6 classes.

# %% [markdown]
# Show the first nine images and labels from the training set:

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# As the original dataset doesn't contain a test set, you will create one. To do so, determine how many batches of data are available in the validation set using `tf.data.experimental.cardinality`, then move 20% of them to a test set.

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(val_batches // 5)
validation_dataset = validation_dataset.skip(val_batches // 5)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 11
# Number of test batches: 2

# %% [markdown]
# ### Configure the dataset for performance

# %% [markdown]
# Use buffered prefetching to load images from disk without having I/O become blocking. To learn more about this method see the [data performance](https://www.tensorflow.org/guide/data_performance) guide.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Use data augmentation

# %% [markdown]
# When you don't have a large image dataset, it's a good practice to artificially introduce sample diversity by applying random, yet realistic, transformations to the training images, such as rotation and horizontal flipping. This helps expose the model to different aspects of the training data and reduce [overfitting](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit). You can learn more about data augmentation in this [tutorial](https://www.tensorflow.org/tutorials/images/data_augmentation).

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal_and_vertical'),
  tf.keras.layers.RandomRotation(0.2),
])

# %% [markdown]
# Note: These layers are active only during training, when you call `Model.fit`. They are inactive when the model is used in inference mode in `Model.evaluate` or `Model.fit`.

# %% [markdown]
# Let's repeatedly apply these layers to the same image and see the result.

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %% [markdown]
# ### Rescale pixel values
#
# In a moment, you will download `tf.keras.applications.MobileNetV2` for use as your base model. This model expects pixel values in `[-1, 1]`, but at this point, the pixel values in your images are in `[0, 255]`. To rescale them, use the preprocessing method included with the model.

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %% [markdown]
# Note: Alternatively, you could rescale pixel values from `[0, 255]` to `[-1, 1]` using `tf.keras.layers.Rescaling`.

# %%
rescale = tf.keras.layers.Rescaling(1./127.5, offset=-1)

# %% [markdown]
# Note: If using other `tf.keras.applications`, be sure to check the API doc to determine if they expect pixels in `[-1, 1]` or `[0, 1]`, or use the included `preprocess_input` function.

# %% [markdown]
# ## Create the base model from the pre-trained convnets
# You will create the base model from the **MobileNet V2** model developed at Google. This is pre-trained on the ImageNet dataset, a large dataset consisting of 1.4M images and 1000 classes. ImageNet is a research training dataset with a wide variety of categories like `jackfruit` and `syringe`. This base of knowledge will help us classify cats and dogs from our specific dataset.
#
# First, you need to pick which layer of MobileNet V2 you will use for feature extraction. The very last classification layer (on "top", as most diagrams of machine learning models go from bottom to top) is not very useful. Instead, you will follow the common practice to depend on the very last layer before the flatten operation. This layer is called the "bottleneck layer". The bottleneck layer features retain more generality as compared to the final/top layer.
#
# First, instantiate a MobileNet V2 model pre-loaded with weights trained on ImageNet. By specifying the **include_top=False** argument, you load a network that doesn't include the classification layers at the top, which is ideal for feature extraction.

# %%
# Create the base model from the pre-trained model InceptionV3
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.InceptionV3(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %% [markdown]
# This feature extractor converts each `160x160x3` image into a `5x5x1280` block of features. Let's see what it does to an example batch of images:

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (32, 3, 3, 2048)

# %% [markdown]
# ## Feature extraction
# In this step, you will freeze the convolutional base created from the previous step and to use as a feature extractor. Additionally, you add a classifier on top of it and train the top-level classifier.

# %% [markdown]
# ### Freeze the convolutional base

# %% [markdown]
# It is important to freeze the convolutional base before you compile and train the model. Freezing (by setting layer.trainable = False) prevents the weights in a given layer from being updated during training. MobileNet V2 has many layers, so setting the entire model's `trainable` flag to False will freeze all of them.

# %%
base_model.trainable = False

# %% [markdown]
# ### Important note about BatchNormalization layers
#
# Many models contain `tf.keras.layers.BatchNormalization` layers. This layer is a special case and precautions should be taken in the context of fine-tuning, as shown later in this tutorial.
#
# When you set `layer.trainable = False`, the `BatchNormalization` layer will run in inference mode, and will not update its mean and variance statistics.
#
# When you unfreeze a model that contains BatchNormalization layers in order to do fine-tuning, you should keep the BatchNormalization layers in inference mode by passing `training = False` when calling the base model. Otherwise, the updates applied to the non-trainable weights will destroy what the model has learned.
#
# For more details, see the [Transfer learning guide](https://www.tensorflow.org/guide/keras/transfer_learning).

# %%
# Let's take a look at the base model architecture
base_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 160, 160, 3)]        0         []
#
#  conv2d_188 (Conv2D)         (None, 79, 79, 32)           864       ['input_5[0][0]']
#
#  batch_normalization_188 (B  (None, 79, 79, 32)           96        ['conv2d_188[0][0]']
#  atchNormalization)
#
#  activation_188 (Activation  (None, 79, 79, 32)           0         ['batch_normalization_188[0][0
#  )                                                                  ]']
#
#  conv2d_189 (Conv2D)         (None, 77, 77, 32)           9216      ['activation_188[0][0]']
#
#  batch_normalization_189 (B  (None, 77, 77, 32)           96        ['conv2d_189[0][0]']
#  atchNormalization)
#
#  activation_189 (Activation  (None, 77, 77, 32)           0         ['batch_normalization_189[0][0
#  )                                                                  ]']
#
#  conv2d_190 (Conv2D)         (None, 77, 77, 64)           18432     ['activation_189[0][0]']
#
#  batch_normalization_190 (B  (None, 77, 77, 64)           192       ['conv2d_190[0][0]']
#  atchNormalization)
#
#  activation_190 (Activation  (None, 77, 77, 64)           0         ['batch_normalization_190[0][0
#  )                                                                  ]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 38, 38, 64)           0         ['activation_190[0][0]']
#  g2D)
#
#  conv2d_191 (Conv2D)         (None, 38, 38, 80)           5120      ['max_pooling2d_8[0][0]']
#
#  batch_normalization_191 (B  (None, 38, 38, 80)           240       ['conv2d_191[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 38, 38, 80)           0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  conv2d_192 (Conv2D)         (None, 36, 36, 192)          138240    ['activation_191[0][0]']
#
#  batch_normalization_192 (B  (None, 36, 36, 192)          576       ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 36, 36, 192)          0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 17, 17, 192)          0         ['activation_192[0][0]']
#  g2D)
#
#  conv2d_196 (Conv2D)         (None, 17, 17, 64)           12288     ['max_pooling2d_9[0][0]']
#
#  batch_normalization_196 (B  (None, 17, 17, 64)           192       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv2d_194 (Conv2D)         (None, 17, 17, 48)           9216      ['max_pooling2d_9[0][0]']
#
#  conv2d_197 (Conv2D)         (None, 17, 17, 96)           55296     ['activation_196[0][0]']
#
#  batch_normalization_194 (B  (None, 17, 17, 48)           144       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  batch_normalization_197 (B  (None, 17, 17, 96)           288       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_194 (Activation  (None, 17, 17, 48)           0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  activation_197 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  average_pooling2d_18 (Aver  (None, 17, 17, 192)          0         ['max_pooling2d_9[0][0]']
#  agePooling2D)
#
#  conv2d_193 (Conv2D)         (None, 17, 17, 64)           12288     ['max_pooling2d_9[0][0]']
#
#  conv2d_195 (Conv2D)         (None, 17, 17, 64)           76800     ['activation_194[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 17, 17, 96)           82944     ['activation_197[0][0]']
#
#  conv2d_199 (Conv2D)         (None, 17, 17, 32)           6144      ['average_pooling2d_18[0][0]']
#
#  batch_normalization_193 (B  (None, 17, 17, 64)           192       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  batch_normalization_195 (B  (None, 17, 17, 64)           192       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 17, 17, 96)           288       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  batch_normalization_199 (B  (None, 17, 17, 32)           96        ['conv2d_199[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  activation_195 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  activation_199 (Activation  (None, 17, 17, 32)           0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 17, 17, 256)          0         ['activation_193[0][0]',
#                                                                      'activation_195[0][0]',
#                                                                      'activation_198[0][0]',
#                                                                      'activation_199[0][0]']
#
#  conv2d_203 (Conv2D)         (None, 17, 17, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_203 (B  (None, 17, 17, 64)           192       ['conv2d_203[0][0]']
#  atchNormalization)
#
#  activation_203 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 17, 17, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_204 (Conv2D)         (None, 17, 17, 96)           55296     ['activation_203[0][0]']
#
#  batch_normalization_201 (B  (None, 17, 17, 48)           144       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  batch_normalization_204 (B  (None, 17, 17, 96)           288       ['conv2d_204[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 17, 17, 48)           0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  activation_204 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  average_pooling2d_19 (Aver  (None, 17, 17, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_200 (Conv2D)         (None, 17, 17, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 17, 17, 64)           76800     ['activation_201[0][0]']
#
#  conv2d_205 (Conv2D)         (None, 17, 17, 96)           82944     ['activation_204[0][0]']
#
#  conv2d_206 (Conv2D)         (None, 17, 17, 64)           16384     ['average_pooling2d_19[0][0]']
#
#  batch_normalization_200 (B  (None, 17, 17, 64)           192       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (None, 17, 17, 64)           192       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  batch_normalization_205 (B  (None, 17, 17, 96)           288       ['conv2d_205[0][0]']
#  atchNormalization)
#
#  batch_normalization_206 (B  (None, 17, 17, 64)           192       ['conv2d_206[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  activation_205 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_205[0][0
#  )                                                                  ]']
#
#  activation_206 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 17, 17, 288)          0         ['activation_200[0][0]',
#                                                                      'activation_202[0][0]',
#                                                                      'activation_205[0][0]',
#                                                                      'activation_206[0][0]']
#
#  conv2d_210 (Conv2D)         (None, 17, 17, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_210 (B  (None, 17, 17, 64)           192       ['conv2d_210[0][0]']
#  atchNormalization)
#
#  activation_210 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_210[0][0
#  )                                                                  ]']
#
#  conv2d_208 (Conv2D)         (None, 17, 17, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_211 (Conv2D)         (None, 17, 17, 96)           55296     ['activation_210[0][0]']
#
#  batch_normalization_208 (B  (None, 17, 17, 48)           144       ['conv2d_208[0][0]']
#  atchNormalization)
#
#  batch_normalization_211 (B  (None, 17, 17, 96)           288       ['conv2d_211[0][0]']
#  atchNormalization)
#
#  activation_208 (Activation  (None, 17, 17, 48)           0         ['batch_normalization_208[0][0
#  )                                                                  ]']
#
#  activation_211 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_211[0][0
#  )                                                                  ]']
#
#  average_pooling2d_20 (Aver  (None, 17, 17, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_207 (Conv2D)         (None, 17, 17, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_209 (Conv2D)         (None, 17, 17, 64)           76800     ['activation_208[0][0]']
#
#  conv2d_212 (Conv2D)         (None, 17, 17, 96)           82944     ['activation_211[0][0]']
#
#  conv2d_213 (Conv2D)         (None, 17, 17, 64)           18432     ['average_pooling2d_20[0][0]']
#
#  batch_normalization_207 (B  (None, 17, 17, 64)           192       ['conv2d_207[0][0]']
#  atchNormalization)
#
#  batch_normalization_209 (B  (None, 17, 17, 64)           192       ['conv2d_209[0][0]']
#  atchNormalization)
#
#  batch_normalization_212 (B  (None, 17, 17, 96)           288       ['conv2d_212[0][0]']
#  atchNormalization)
#
#  batch_normalization_213 (B  (None, 17, 17, 64)           192       ['conv2d_213[0][0]']
#  atchNormalization)
#
#  activation_207 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_207[0][0
#  )                                                                  ]']
#
#  activation_209 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_209[0][0
#  )                                                                  ]']
#
#  activation_212 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_212[0][0
#  )                                                                  ]']
#
#  activation_213 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_213[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 17, 17, 288)          0         ['activation_207[0][0]',
#                                                                      'activation_209[0][0]',
#                                                                      'activation_212[0][0]',
#                                                                      'activation_213[0][0]']
#
#  conv2d_215 (Conv2D)         (None, 17, 17, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_215 (B  (None, 17, 17, 64)           192       ['conv2d_215[0][0]']
#  atchNormalization)
#
#  activation_215 (Activation  (None, 17, 17, 64)           0         ['batch_normalization_215[0][0
#  )                                                                  ]']
#
#  conv2d_216 (Conv2D)         (None, 17, 17, 96)           55296     ['activation_215[0][0]']
#
#  batch_normalization_216 (B  (None, 17, 17, 96)           288       ['conv2d_216[0][0]']
#  atchNormalization)
#
#  activation_216 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_216[0][0
#  )                                                                  ]']
#
#  conv2d_214 (Conv2D)         (None, 8, 8, 384)            995328    ['mixed2[0][0]']
#
#  conv2d_217 (Conv2D)         (None, 8, 8, 96)             82944     ['activation_216[0][0]']
#
#  batch_normalization_214 (B  (None, 8, 8, 384)            1152      ['conv2d_214[0][0]']
#  atchNormalization)
#
#  batch_normalization_217 (B  (None, 8, 8, 96)             288       ['conv2d_217[0][0]']
#  atchNormalization)
#
#  activation_214 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_214[0][0
#  )                                                                  ]']
#
#  activation_217 (Activation  (None, 8, 8, 96)             0         ['batch_normalization_217[0][0
#  )                                                                  ]']
#
#  max_pooling2d_10 (MaxPooli  (None, 8, 8, 288)            0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 8, 8, 768)            0         ['activation_214[0][0]',
#                                                                      'activation_217[0][0]',
#                                                                      'max_pooling2d_10[0][0]']
#
#  conv2d_222 (Conv2D)         (None, 8, 8, 128)            98304     ['mixed3[0][0]']
#
#  batch_normalization_222 (B  (None, 8, 8, 128)            384       ['conv2d_222[0][0]']
#  atchNormalization)
#
#  activation_222 (Activation  (None, 8, 8, 128)            0         ['batch_normalization_222[0][0
#  )                                                                  ]']
#
#  conv2d_223 (Conv2D)         (None, 8, 8, 128)            114688    ['activation_222[0][0]']
#
#  batch_normalization_223 (B  (None, 8, 8, 128)            384       ['conv2d_223[0][0]']
#  atchNormalization)
#
#  activation_223 (Activation  (None, 8, 8, 128)            0         ['batch_normalization_223[0][0
#  )                                                                  ]']
#
#  conv2d_219 (Conv2D)         (None, 8, 8, 128)            98304     ['mixed3[0][0]']
#
#  conv2d_224 (Conv2D)         (None, 8, 8, 128)            114688    ['activation_223[0][0]']
#
#  batch_normalization_219 (B  (None, 8, 8, 128)            384       ['conv2d_219[0][0]']
#  atchNormalization)
#
#  batch_normalization_224 (B  (None, 8, 8, 128)            384       ['conv2d_224[0][0]']
#  atchNormalization)
#
#  activation_219 (Activation  (None, 8, 8, 128)            0         ['batch_normalization_219[0][0
#  )                                                                  ]']
#
#  activation_224 (Activation  (None, 8, 8, 128)            0         ['batch_normalization_224[0][0
#  )                                                                  ]']
#
#  conv2d_220 (Conv2D)         (None, 8, 8, 128)            114688    ['activation_219[0][0]']
#
#  conv2d_225 (Conv2D)         (None, 8, 8, 128)            114688    ['activation_224[0][0]']
#
#  batch_normalization_220 (B  (None, 8, 8, 128)            384       ['conv2d_220[0][0]']
#  atchNormalization)
#
#  batch_normalization_225 (B  (None, 8, 8, 128)            384       ['conv2d_225[0][0]']
#  atchNormalization)
#
#  activation_220 (Activation  (None, 8, 8, 128)            0         ['batch_normalization_220[0][0
#  )                                                                  ]']
#
#  activation_225 (Activation  (None, 8, 8, 128)            0         ['batch_normalization_225[0][0
#  )                                                                  ]']
#
#  average_pooling2d_21 (Aver  (None, 8, 8, 768)            0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_218 (Conv2D)         (None, 8, 8, 192)            147456    ['mixed3[0][0]']
#
#  conv2d_221 (Conv2D)         (None, 8, 8, 192)            172032    ['activation_220[0][0]']
#
#  conv2d_226 (Conv2D)         (None, 8, 8, 192)            172032    ['activation_225[0][0]']
#
#  conv2d_227 (Conv2D)         (None, 8, 8, 192)            147456    ['average_pooling2d_21[0][0]']
#
#  batch_normalization_218 (B  (None, 8, 8, 192)            576       ['conv2d_218[0][0]']
#  atchNormalization)
#
#  batch_normalization_221 (B  (None, 8, 8, 192)            576       ['conv2d_221[0][0]']
#  atchNormalization)
#
#  batch_normalization_226 (B  (None, 8, 8, 192)            576       ['conv2d_226[0][0]']
#  atchNormalization)
#
#  batch_normalization_227 (B  (None, 8, 8, 192)            576       ['conv2d_227[0][0]']
#  atchNormalization)
#
#  activation_218 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_218[0][0
#  )                                                                  ]']
#
#  activation_221 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_221[0][0
#  )                                                                  ]']
#
#  activation_226 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_226[0][0
#  )                                                                  ]']
#
#  activation_227 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_227[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 8, 8, 768)            0         ['activation_218[0][0]',
#                                                                      'activation_221[0][0]',
#                                                                      'activation_226[0][0]',
#                                                                      'activation_227[0][0]']
#
#  conv2d_232 (Conv2D)         (None, 8, 8, 160)            122880    ['mixed4[0][0]']
#
#  batch_normalization_232 (B  (None, 8, 8, 160)            480       ['conv2d_232[0][0]']
#  atchNormalization)
#
#  activation_232 (Activation  (None, 8, 8, 160)            0         ['batch_normalization_232[0][0
#  )                                                                  ]']
#
#  conv2d_233 (Conv2D)         (None, 8, 8, 160)            179200    ['activation_232[0][0]']
#
#  batch_normalization_233 (B  (None, 8, 8, 160)            480       ['conv2d_233[0][0]']
#  atchNormalization)
#
#  activation_233 (Activation  (None, 8, 8, 160)            0         ['batch_normalization_233[0][0
#  )                                                                  ]']
#
#  conv2d_229 (Conv2D)         (None, 8, 8, 160)            122880    ['mixed4[0][0]']
#
#  conv2d_234 (Conv2D)         (None, 8, 8, 160)            179200    ['activation_233[0][0]']
#
#  batch_normalization_229 (B  (None, 8, 8, 160)            480       ['conv2d_229[0][0]']
#  atchNormalization)
#
#  batch_normalization_234 (B  (None, 8, 8, 160)            480       ['conv2d_234[0][0]']
#  atchNormalization)
#
#  activation_229 (Activation  (None, 8, 8, 160)            0         ['batch_normalization_229[0][0
#  )                                                                  ]']
#
#  activation_234 (Activation  (None, 8, 8, 160)            0         ['batch_normalization_234[0][0
#  )                                                                  ]']
#
#  conv2d_230 (Conv2D)         (None, 8, 8, 160)            179200    ['activation_229[0][0]']
#
#  conv2d_235 (Conv2D)         (None, 8, 8, 160)            179200    ['activation_234[0][0]']
#
#  batch_normalization_230 (B  (None, 8, 8, 160)            480       ['conv2d_230[0][0]']
#  atchNormalization)
#
#  batch_normalization_235 (B  (None, 8, 8, 160)            480       ['conv2d_235[0][0]']
#  atchNormalization)
#
#  activation_230 (Activation  (None, 8, 8, 160)            0         ['batch_normalization_230[0][0
#  )                                                                  ]']
#
#  activation_235 (Activation  (None, 8, 8, 160)            0         ['batch_normalization_235[0][0
#  )                                                                  ]']
#
#  average_pooling2d_22 (Aver  (None, 8, 8, 768)            0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_228 (Conv2D)         (None, 8, 8, 192)            147456    ['mixed4[0][0]']
#
#  conv2d_231 (Conv2D)         (None, 8, 8, 192)            215040    ['activation_230[0][0]']
#
#  conv2d_236 (Conv2D)         (None, 8, 8, 192)            215040    ['activation_235[0][0]']
#
#  conv2d_237 (Conv2D)         (None, 8, 8, 192)            147456    ['average_pooling2d_22[0][0]']
#
#  batch_normalization_228 (B  (None, 8, 8, 192)            576       ['conv2d_228[0][0]']
#  atchNormalization)
#
#  batch_normalization_231 (B  (None, 8, 8, 192)            576       ['conv2d_231[0][0]']
#  atchNormalization)
#
#  batch_normalization_236 (B  (None, 8, 8, 192)            576       ['conv2d_236[0][0]']
#  atchNormalization)
#
#  batch_normalization_237 (B  (None, 8, 8, 192)            576       ['conv2d_237[0][0]']
#  atchNormalization)
#
#  activation_228 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_228[0][0
#  )                                                                  ]']
#
#  activation_231 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_231[0][0
#  )                                                                  ]']
#
#  activation_236 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_236[0][0
#  )                                                                  ]']
#
#  activation_237 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_237[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 8, 8, 768)            0         ['activation_228[0][0]',
#                                                                      'activation_231[0][0]',
#                                                                      'activation_236[0][0]',
#                                                                      'activation_237[0][0]']
#
#  conv2d_242 (Conv2D)         (None, 8, 8, 160)            122880    ['mixed5[0][0]']
#
#  batch_normalization_242 (B  (None, 8, 8, 160)            480       ['conv2d_242[0][0]']
#  atchNormalization)
#
#  activation_242 (Activation  (None, 8, 8, 160)            0         ['batch_normalization_242[0][0
#  )                                                                  ]']
#
#  conv2d_243 (Conv2D)         (None, 8, 8, 160)            179200    ['activation_242[0][0]']
#
#  batch_normalization_243 (B  (None, 8, 8, 160)            480       ['conv2d_243[0][0]']
#  atchNormalization)
#
#  activation_243 (Activation  (None, 8, 8, 160)            0         ['batch_normalization_243[0][0
#  )                                                                  ]']
#
#  conv2d_239 (Conv2D)         (None, 8, 8, 160)            122880    ['mixed5[0][0]']
#
#  conv2d_244 (Conv2D)         (None, 8, 8, 160)            179200    ['activation_243[0][0]']
#
#  batch_normalization_239 (B  (None, 8, 8, 160)            480       ['conv2d_239[0][0]']
#  atchNormalization)
#
#  batch_normalization_244 (B  (None, 8, 8, 160)            480       ['conv2d_244[0][0]']
#  atchNormalization)
#
# ...
#
#  batch_normalization_269 (B  (None, 3, 3, 384)            1152      ['conv2d_269[0][0]']
#  atchNormalization)
#
#  activation_265 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_265[0][0
#  )                                                                  ]']
#
#  activation_269 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_269[0][0
#  )                                                                  ]']
#
#  conv2d_266 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_265[0][0]']
#
#  conv2d_267 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_265[0][0]']
#
#  conv2d_270 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_269[0][0]']
#
#  conv2d_271 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_269[0][0]']
#
#  average_pooling2d_25 (Aver  (None, 3, 3, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_264 (Conv2D)         (None, 3, 3, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_266 (B  (None, 3, 3, 384)            1152      ['conv2d_266[0][0]']
#  atchNormalization)
#
#  batch_normalization_267 (B  (None, 3, 3, 384)            1152      ['conv2d_267[0][0]']
#  atchNormalization)
#
#  batch_normalization_270 (B  (None, 3, 3, 384)            1152      ['conv2d_270[0][0]']
#  atchNormalization)
#
#  batch_normalization_271 (B  (None, 3, 3, 384)            1152      ['conv2d_271[0][0]']
#  atchNormalization)
#
#  conv2d_272 (Conv2D)         (None, 3, 3, 192)            245760    ['average_pooling2d_25[0][0]']
#
#  batch_normalization_264 (B  (None, 3, 3, 320)            960       ['conv2d_264[0][0]']
#  atchNormalization)
#
#  activation_266 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_266[0][0
#  )                                                                  ]']
#
#  activation_267 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_267[0][0
#  )                                                                  ]']
#
#  activation_270 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_270[0][0
#  )                                                                  ]']
#
#  activation_271 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_271[0][0
#  )                                                                  ]']
#
#  batch_normalization_272 (B  (None, 3, 3, 192)            576       ['conv2d_272[0][0]']
#  atchNormalization)
#
#  activation_264 (Activation  (None, 3, 3, 320)            0         ['batch_normalization_264[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 3, 3, 768)            0         ['activation_266[0][0]',
#                                                                      'activation_267[0][0]']
#
#  concatenate_4 (Concatenate  (None, 3, 3, 768)            0         ['activation_270[0][0]',
#  )                                                                   'activation_271[0][0]']
#
#  activation_272 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_272[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 3, 3, 2048)           0         ['activation_264[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_4[0][0]',
#                                                                      'activation_272[0][0]']
#
#  conv2d_277 (Conv2D)         (None, 3, 3, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_277 (B  (None, 3, 3, 448)            1344      ['conv2d_277[0][0]']
#  atchNormalization)
#
#  activation_277 (Activation  (None, 3, 3, 448)            0         ['batch_normalization_277[0][0
#  )                                                                  ]']
#
#  conv2d_274 (Conv2D)         (None, 3, 3, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_278 (Conv2D)         (None, 3, 3, 384)            1548288   ['activation_277[0][0]']
#
#  batch_normalization_274 (B  (None, 3, 3, 384)            1152      ['conv2d_274[0][0]']
#  atchNormalization)
#
#  batch_normalization_278 (B  (None, 3, 3, 384)            1152      ['conv2d_278[0][0]']
#  atchNormalization)
#
#  activation_274 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_274[0][0
#  )                                                                  ]']
#
#  activation_278 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_278[0][0
#  )                                                                  ]']
#
#  conv2d_275 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_274[0][0]']
#
#  conv2d_276 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_274[0][0]']
#
#  conv2d_279 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_278[0][0]']
#
#  conv2d_280 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_278[0][0]']
#
#  average_pooling2d_26 (Aver  (None, 3, 3, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_273 (Conv2D)         (None, 3, 3, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_275 (B  (None, 3, 3, 384)            1152      ['conv2d_275[0][0]']
#  atchNormalization)
#
#  batch_normalization_276 (B  (None, 3, 3, 384)            1152      ['conv2d_276[0][0]']
#  atchNormalization)
#
#  batch_normalization_279 (B  (None, 3, 3, 384)            1152      ['conv2d_279[0][0]']
#  atchNormalization)
#
#  batch_normalization_280 (B  (None, 3, 3, 384)            1152      ['conv2d_280[0][0]']
#  atchNormalization)
#
#  conv2d_281 (Conv2D)         (None, 3, 3, 192)            393216    ['average_pooling2d_26[0][0]']
#
#  batch_normalization_273 (B  (None, 3, 3, 320)            960       ['conv2d_273[0][0]']
#  atchNormalization)
#
#  activation_275 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_275[0][0
#  )                                                                  ]']
#
#  activation_276 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_276[0][0
#  )                                                                  ]']
#
#  activation_279 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_279[0][0
#  )                                                                  ]']
#
#  activation_280 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_280[0][0
#  )                                                                  ]']
#
#  batch_normalization_281 (B  (None, 3, 3, 192)            576       ['conv2d_281[0][0]']
#  atchNormalization)
#
#  activation_273 (Activation  (None, 3, 3, 320)            0         ['batch_normalization_273[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 3, 3, 768)            0         ['activation_275[0][0]',
#                                                                      'activation_276[0][0]']
#
#  concatenate_5 (Concatenate  (None, 3, 3, 768)            0         ['activation_279[0][0]',
#  )                                                                   'activation_280[0][0]']
#
#  activation_281 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_281[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 3, 3, 2048)           0         ['activation_273[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_5[0][0]',
#                                                                      'activation_281[0][0]']
#
# ==================================================================================================
# Total params: 21802784 (83.17 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Add a classification head

# %% [markdown]
# To generate predictions from the block of features, average over the spatial `5x5` spatial locations, using a `tf.keras.layers.GlobalAveragePooling2D` layer to convert the features to  a single 1280-element vector per image.

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 2048)

# %% [markdown]
# Apply a `tf.keras.layers.Dense` layer to convert these features into a single prediction per image. You don't need an activation function here because this prediction will be treated as a `logit`, or a raw prediction value. Positive numbers predict class 1, negative numbers predict class 0.

# %%
prediction_layer = tf.keras.layers.Dense(6)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (32, 6)

# %% [markdown]
# Build a model by chaining together the data augmentation, rescaling, `base_model` and feature extractor layers using the [Keras Functional API](https://www.tensorflow.org/guide/keras/functional). As previously mentioned, use `training=False` as our model contains a `BatchNormalization` layer.

# %%
inputs = tf.keras.Input(shape=(160, 160, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# ### Compile the model
#
# Compile the model before training it. Since there are two classes, use the `tf.keras.losses.BinaryCrossentropy` loss with `from_logits=True` since the model provides a linear output.

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential_2 (Sequential)   (None, 160, 160, 3)       0
#
#  tf.math.truediv_2 (TFOpLam  (None, 160, 160, 3)       0
#  bda)
#
#  tf.math.subtract_2 (TFOpLa  (None, 160, 160, 3)       0
#  mbda)
#
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  global_average_pooling2d_2  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 6)                 12294
#
# =================================================================
# Total params: 21815078 (83.22 MB)
# Trainable params: 12294 (48.02 KB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________

# %% [markdown]
# The 2.5 million parameters in MobileNet are frozen, but there are 1.2 thousand _trainable_ parameters in the Dense layer. These are divided between two `tf.Variable` objects, the weights and biases.

# %%
len(model.trainable_variables)
# Out:
# 2

# %% [markdown]
# ### Train the model
#
# After training for 10 epochs, you should see ~94% accuracy on the validation set.

# %%
initial_epochs = 10

loss0, accuracy0 = model.evaluate(validation_dataset)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 3
#       1 initial_epochs = 10
# ----> 3 loss0, accuracy0 = model.evaluate(validation_dataset)
#
# File ~/GitHub/nn/.venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /var/folders/cw/g46f4js5437fbcwxgx6jb7sw0000gn/T/__autograph_generated_file7dsac0fx.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__test_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/Users/admin/GitHub/nn/.venv/lib/python3.9/site-packages/keras/src/engine/training.py", line 2066, in test_function  *
#         return step_function(self, iterator)
#     File "/Users/admin/GitHub/nn/.venv/lib/python3.9/site-packages/keras/src/engine/training.py", line 2049, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/admin/GitHub/nn/.venv/lib/python3.9/site-packages/keras/src/engine/training.py", line 2037, in run_step  **
#         outputs = model.test_step(data)
#     File "/Users/admin/GitHub/nn/.venv/lib/python3.9/site-packages/keras/src/engine/training.py", line 1919, in test_step
#         self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/admin/GitHub/nn/.venv/lib/python3.9/site-packages/keras/src/engine/training.py", line 1209, in compute_loss
#         return self.compiled_loss(
#     File "/Users/admin/GitHub/nn/.venv/lib/python3.9/site-packages/keras/src/engine/compile_utils.py", line 277, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/admin/GitHub/nn/.venv/lib/python3.9/site-packages/keras/src/losses.py", line 143, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/Users/admin/GitHub/nn/.venv/lib/python3.9/site-packages/keras/src/losses.py", line 270, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/admin/GitHub/nn/.venv/lib/python3.9/site-packages/keras/src/losses.py", line 2221, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "/Users/admin/GitHub/nn/.venv/lib/python3.9/site-packages/keras/src/backend.py", line 5573, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 1) and (None, 6) are incompatible

# %%
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))

# %%
history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset)

# %% [markdown]
# ### Learning curves
#
# Let's take a look at the learning curves of the training and validation accuracy/loss when using the MobileNetV2 base model as a fixed feature extractor.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# Note: If you are wondering why the validation metrics are clearly better than the training metrics, the main factor is because layers like `tf.keras.layers.BatchNormalization` and `tf.keras.layers.Dropout` affect accuracy during training. They are turned off when calculating validation loss.
#
# To a lesser extent, it is also because training metrics report the average for an epoch, while validation metrics are evaluated after the epoch, so validation metrics see a model that has trained slightly longer.

# %% [markdown]
# ## Fine tuning
# In the feature extraction experiment, you were only training a few layers on top of an MobileNetV2 base model. The weights of the pre-trained network were **not** updated during training.
#
# One way to increase performance even further is to train (or "fine-tune") the weights of the top layers of the pre-trained model alongside the training of the classifier you added. The training process will force the weights to be tuned from generic feature maps to features associated specifically with the dataset.
#
# Note: This should only be attempted after you have trained the top-level classifier with the pre-trained model set to non-trainable. If you add a randomly initialized classifier on top of a pre-trained model and attempt to train all layers jointly, the magnitude of the gradient updates will be too large (due to the random weights from the classifier) and your pre-trained model will forget what it has learned.
#
# Also, you should try to fine-tune a small number of top layers rather than the whole MobileNet model. In most convolutional networks, the higher up a layer is, the more specialized it is. The first few layers learn very simple and generic features that generalize to almost all types of images. As you go higher up, the features are increasingly more specific to the dataset on which the model was trained. The goal of fine-tuning is to adapt these specialized features to work with the new dataset, rather than overwrite the generic learning.

# %% [markdown]
# ### Un-freeze the top layers of the model

# %% [markdown]
# All you need to do is unfreeze the `base_model` and set the bottom layers to be un-trainable. Then, you should recompile the model (necessary for these changes to take effect), and resume training.

# %%
base_model.trainable = True

# %%
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False

# %% [markdown]
# ### Compile the model
#
# As you are training a much larger model and want to readapt the pretrained weights, it is important to use a lower learning rate at this stage. Otherwise, your model could overfit very quickly.

# %%
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate/10),
              metrics=['accuracy'])

# %%
model.summary()

# %%
len(model.trainable_variables)

# %% [markdown]
# ### Continue training the model

# %% [markdown]
# If you trained to convergence earlier, this step will improve your accuracy by a few percentage points.

# %%
fine_tune_epochs = 10
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = model.fit(train_dataset,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=validation_dataset)

# %% [markdown]
# Let's take a look at the learning curves of the training and validation accuracy/loss when fine-tuning the last few layers of the MobileNetV2 base model and training the classifier on top of it. The validation loss is much higher than the training loss, so you may get some overfitting.
#
# You may also get some overfitting as the new training set is relatively small and similar to the original MobileNetV2 datasets.

# %% [markdown]
# After fine tuning the model nearly reaches 98% accuracy on the validation set.

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.8, 1])
plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 1.0])
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Evaluation and prediction

# %% [markdown]
# Finally you can verify the performance of the model on new data using test set.

# %%
loss, accuracy = model.evaluate(test_dataset)
print('Test accuracy :', accuracy)

# %% [markdown]
# And now you are all set to use this model to predict if your pet is a cat or dog.

# %%
# Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch).flatten()

# Apply a sigmoid since our model returns logits
predictions = tf.nn.sigmoid(predictions)
predictions = tf.where(predictions < 0.5, 0, 1)

print('Predictions:\n', predictions.numpy())
print('Labels:\n', label_batch)

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(image_batch[i].astype("uint8"))
  plt.title(class_names[predictions[i]])
  plt.axis("off")

# %% [markdown]
# ## Summary
#
# * **Using a pre-trained model for feature extraction**:  When working with a small dataset, it is a common practice to take advantage of features learned by a model trained on a larger dataset in the same domain. This is done by instantiating the pre-trained model and adding a fully-connected classifier on top. The pre-trained model is "frozen" and only the weights of the classifier get updated during training.
# In this case, the convolutional base extracted all the features associated with each image and you just trained a classifier that determines the image class given that set of extracted features.
#
# * **Fine-tuning a pre-trained model**: To further improve performance, one might want to repurpose the top-level layers of the pre-trained models to the new dataset via fine-tuning.
# In this case, you tuned your weights such that your model learned high-level features specific to the dataset. This technique is usually recommended when the training dataset is large and very similar to the original dataset that the pre-trained model was trained on.
#
# To learn more, visit the [Transfer learning guide](https://www.tensorflow.org/guide/keras/transfer_learning).
